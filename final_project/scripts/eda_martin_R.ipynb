# %%
library(fpp3)
# Out:
# ── Attaching packages ────────────────────────────────────────────── fpp3 0.5 ──
#
# ✔ tibble      3.2.1     ✔ tsibble     1.1.3
# ✔ dplyr       1.1.4     ✔ tsibbledata 0.4.1
# ✔ tidyr       1.2.1     ✔ feasts      0.3.1
# ✔ lubridate   1.8.0     ✔ fable       0.3.3
# ✔ ggplot2     3.4.4     ✔ fabletools  0.3.4
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# ── Conflicts ───────────────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()

# %%
data <- read.csv("../data/total_sales.csv")
sales <- data %>% mutate(date = as.Date(date)) %>% as_tsibble(index=date)

# %%
sales %>% autoplot
# Out:
# Plot variable not specified, automatically selected `.vars = total_sales`
# plot without title
